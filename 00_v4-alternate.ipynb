# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_raw = pd.read_csv('../fedex.csv')

# %% [markdown]
# #### Exploracion ####

# %%
data_raw.head(5)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  Actual_Shipment_Time  \
# 0  2008      1           3          4                2003.0
# 1  2008      1           3          4                 754.0
# 2  2008      1           3          4                 628.0
# 3  2008      1           3          4                 926.0
# 4  2008      1           3          4                1829.0
#
#    Planned_Shipment_Time  Planned_Delivery_Time Carrier_Name  Carrier_Num  \
# 0                   1955                   2225           WN          335
# 1                    735                   1000           WN         3231
# 2                    620                    750           WN          448
# 3                    930                   1100           WN         1746
# 4                   1755                   1925           WN         3920
#
#    Planned_TimeofTravel  Shipment_Delay Source Destination  Distance  \
# 0                 150.0             8.0    IAD         TPA       810
# 1                 145.0            19.0    IAD         TPA       810
# 2                  90.0             8.0    IND         BWI       515
# 3                  90.0            -4.0    IND         BWI       515
# 4                  90.0            34.0    IND         BWI       515
#
#    Delivery_Status
# 0              0.0
# 1              1.0
# 2              0.0
# 3              0.0
# 4              1.0

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3604175 entries, 0 to 3604174
# Data columns (total 15 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Year                   int64
#  1   Month                  int64
#  2   DayofMonth             int64
#  3   DayOfWeek              int64
#  4   Actual_Shipment_Time   float64
#  5   Planned_Shipment_Time  int64
#  6   Planned_Delivery_Time  int64
#  7   Carrier_Name           object
#  8   Carrier_Num            int64
#  9   Planned_TimeofTravel   float64
#  10  Shipment_Delay         float64
#  11  Source                 object
#  12  Destination            object
#  13  Distance               int64
#  14  Delivery_Status        float64
# dtypes: float64(4), int64(8), object(3)
# memory usage: 412.5+ MB

# %%
data_raw.isnull().sum()
# Out:
# Year                         0
# Month                        0
# DayofMonth                   0
# DayOfWeek                    0
# Actual_Shipment_Time     81602
# Planned_Shipment_Time        0
# Planned_Delivery_Time        0
# Carrier_Name                 0
# Carrier_Num                  0
# Planned_TimeofTravel       547
# Shipment_Delay           81602
# Source                       0
# Destination                  0
# Distance                     0
# Delivery_Status          81602
# dtype: int64

# %%
data_raw.dtypes
# Out:
# Year                       int64
# Month                      int64
# DayofMonth                 int64
# DayOfWeek                  int64
# Actual_Shipment_Time     float64
# Planned_Shipment_Time      int64
# Planned_Delivery_Time      int64
# Carrier_Name              object
# Carrier_Num                int64
# Planned_TimeofTravel     float64
# Shipment_Delay           float64
# Source                    object
# Destination               object
# Distance                   int64
# Delivery_Status          float64
# dtype: object

# %%
data_raw.Carrier_Name.nunique()
# Out:
# 20

# %%
data_raw.Source.value_counts()
# Out:
# ATL    207003
# ORD    179274
# DFW    141948
# DEN    120500
# LAX    111703
#         ...
# AKN        41
# BJI        26
# INL        25
# GST        23
# TUP        10
# Name: Source, Length: 297, dtype: int64

# %%
data_raw.Destination.value_counts()
# Out:
# ATL    206935
# ORD    179310
# DFW    142013
# DEN    120517
# LAX    111749
#         ...
# INL        26
# GST        23
# TUP         9
# CYS         2
# OGD         2
# Name: Destination, Length: 299, dtype: int64

# %%
data_raw.Carrier_Name.value_counts()
# Out:
# WN    602447
# AA    308611
# OO    293452
# MQ    255129
# UA    234137
# US    231041
# DL    225602
# XE    208671
# NW    186376
# CO    155318
# EV    140491
# FL    133553
# 9E    132077
# YV    130307
# OH    106344
# B6    100172
# AS     76412
# F9     47861
# HA     28374
# AQ      7800
# Name: Carrier_Name, dtype: int64

# %%
data_raw.Shipment_Delay.value_counts()
# Out:
#  0.0       275883
# -5.0       262854
# -3.0       242962
# -2.0       239685
# -4.0       235236
#             ...
#  499.0          1
#  921.0          1
#  782.0          1
#  1268.0         1
#  526.0          1
# Name: Shipment_Delay, Length: 997, dtype: int64

# %%
data_raw.shape
# Out:
# (3604175, 15)

# %%
data_raw.isnull().sum()
# Out:
# Year                         0
# Month                        0
# DayofMonth                   0
# DayOfWeek                    0
# Actual_Shipment_Time     81602
# Planned_Shipment_Time        0
# Planned_Delivery_Time        0
# Carrier_Name                 0
# Carrier_Num                  0
# Planned_TimeofTravel       547
# Shipment_Delay           81602
# Source                       0
# Destination                  0
# Distance                     0
# Delivery_Status          81602
# dtype: int64

# %% [markdown]
# #### Limpieza de Shipment_Delay menor a cero ####

# %%
data = data_raw[data_raw['Shipment_Delay'] > 0] 
data
#user_rating_high = data[data['user_rating'] >= 4]
# Out:
#          Year  Month  DayofMonth  DayOfWeek  Actual_Shipment_Time  \
# 0        2008      1           3          4                2003.0
# 1        2008      1           3          4                 754.0
# 2        2008      1           3          4                 628.0
# 4        2008      1           3          4                1829.0
# 5        2008      1           3          4                1940.0
# ...       ...    ...         ...        ...                   ...
# 3604163  2008      6          19          4                1428.0
# 3604164  2008      6          19          4                2242.0
# 3604166  2008      6          19          4                1728.0
# 3604169  2008      6          19          4                1135.0
# 3604174  2008      6          19          4                1127.0
#
#          Planned_Shipment_Time  Planned_Delivery_Time Carrier_Name  \
# 0                         1955                   2225           WN
# 1                          735                   1000           WN
# 2                          620                    750           WN
# 4                         1755                   1925           WN
# 5                         1915                   2110           WN
# ...                        ...                    ...          ...
# 3604163                   1402                   2145           DL
# 3604164                   2235                     12           DL
# 3604166                   1725                   1751           DL
# 3604169                   1120                   1834           DL
# 3604174                    951                   1130           DL
#
#          Carrier_Num  Planned_TimeofTravel  Shipment_Delay Source Destination  \
# 0                335                 150.0             8.0    IAD         TPA
# 1               3231                 145.0            19.0    IAD         TPA
# 2                448                  90.0             8.0    IND         BWI
# 4               3920                  90.0            34.0    IND         BWI
# 5                378                 115.0            25.0    IND         JAX
# ...              ...                   ...             ...    ...         ...
# 3604163         1540                 283.0            26.0    PDX         ATL
# 3604164         1540                  97.0             7.0    ATL         PBI
# 3604166         1543                  86.0             3.0    ATL         MEM
# 3604169         1546                 254.0            15.0    SNA         CVG
# 3604174         1551                 159.0            96.0    ATL         MSP
#
#          Distance  Delivery_Status
# 0             810              0.0
# 1             810              1.0
# 2             515              0.0
# 4             515              1.0
# 5             688              1.0
# ...           ...              ...
# 3604163      2172              1.0
# 3604164       545              0.0
# 3604166       332              0.0
# 3604169      1877              0.0
# 3604174       906              1.0
#
# [1485174 rows x 15 columns]

# %%
#data[data['Shipment_Delay'] < 0].sum()

# %%
data.Shipment_Delay.value_counts()
# Out:
# 1.0       119137
# 2.0        88787
# 3.0        73171
# 4.0        62172
# 5.0        58754
#            ...
# 877.0          1
# 840.0          1
# 770.0          1
# 1069.0         1
# 526.0          1
# Name: Shipment_Delay, Length: 930, dtype: int64

# %%
data.shape
# Out:
# (1485174, 15)

# %% [markdown]
# #### SweetViz ####

# %%
import sweetviz

# %%
reporte = sweetviz.analyze(data)
reporte.show_notebook()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(C,e){&quot;use strict&quot;;var t=[],E=C.document,r=Object.getPrototypeOf,s=t.slice,g=t.concat,u=t.push,i=t.indexOf,n={},o=n.toString,v=n.hasOwnProperty,a=v.toString,l=a.call(Object),y={},m=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType},x=function(e){return null!=e&amp;&amp;e===e.window},c={type:!0,src:!0,nonce:!0,noModule:!0};function b(e,t,n){var r,i,o=(n=n||E).createElement(&quot;script&quot;);if(o.text=e,t)for(r in c)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function w(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[o.call(e)]||&quot;object&quot;:typeof e}var f=&quot;3.4.1&quot;,k=function(e,t){return new k.fn.init(e,t)},p=/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g;function d(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=w(e);return!m(e)&amp;&amp;!x(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}k.fn=k.prototype={jquery:f,constructor:k,length:0,toArray:function(){return s.call(this)},get:function(e){return null==e?s.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=k.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return k.each(this,e)},map:function(n){return this.pushStack(k.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(s.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:u,sort:t.sort,splice:t.splice},k.extend=k.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||m(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(k.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||k.isPlainObject(n)?n:{},i=!1,a[t]=k.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},k.extend({expando:&quot;jQuery&quot;+(f+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==o.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=v.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;a.call(n)===l)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t){b(e,{nonce:t&amp;&amp;t.nonce})},each:function(e,t){var n,r=0;if(d(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},trim:function(e){return null==e?&quot;&quot;:(e+&quot;&quot;).replace(p,&quot;&quot;)},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(d(Object(e))?k.merge(n,&quot;string&quot;==typeof e?[e]:e):u.call(n,e)),n},inArray:function(e,t,n){return null==t?-1:i.call(t,e,n)},merge:function(e,t){for(var n=+t.length,r=0,i=e.length;r&lt;n;r++)e[i++]=t[r];return e.length=i,e},grep:function(e,t,n){for(var r=[],i=0,o=e.length,a=!n;i&lt;o;i++)!t(e[i],i)!==a&amp;&amp;r.push(e[i]);return r},map:function(e,t,n){var r,i,o=0,a=[];if(d(e))for(r=e.length;o&lt;r;o++)null!=(i=t(e[o],o,n))&amp;&amp;a.push(i);else for(o in e)null!=(i=t(e[o],o,n))&amp;&amp;a.push(i);return g.apply([] ...

# %% [markdown]
# #### Limpieza de nulos ####

# %%
data.isnull().sum()
# Out:
# Year                       0
# Month                      0
# DayofMonth                 0
# DayOfWeek                  0
# Actual_Shipment_Time       0
# Planned_Shipment_Time      0
# Planned_Delivery_Time      0
# Carrier_Name               0
# Carrier_Num                0
# Planned_TimeofTravel     191
# Shipment_Delay             0
# Source                     0
# Destination                0
# Distance                   0
# Delivery_Status            0
# dtype: int64

# %%
data.shape
# Out:
# (1485174, 15)

# %%
data_sin_na = (data.dropna()).copy()

# %%
data_sin_na.shape
# Out:
# (1484983, 15)

# %%
data_sin_na.isnull().sum()
# Out:
# Year                     0
# Month                    0
# DayofMonth               0
# DayOfWeek                0
# Actual_Shipment_Time     0
# Planned_Shipment_Time    0
# Planned_Delivery_Time    0
# Carrier_Name             0
# Carrier_Num              0
# Planned_TimeofTravel     0
# Shipment_Delay           0
# Source                   0
# Destination              0
# Distance                 0
# Delivery_Status          0
# dtype: int64

# %% [markdown]
# #### Eliminacion de columnas que no sirven ####

# %%
import seaborn as sns

# %%
sns.heatmap(data_sin_na.corr())
# Out:
# <AxesSubplot:>

# %%
data_sin_na.corr()['Delivery_Status'].apply(lambda x: np.abs(x)).sort_values(ascending = False)
# Out:
# Delivery_Status          1.000000
# Shipment_Delay           0.553742
# Actual_Shipment_Time     0.218031
# Planned_Shipment_Time    0.155249
# Planned_Delivery_Time    0.134765
# Carrier_Num              0.079117
# Distance                 0.031277
# Month                    0.019999
# Planned_TimeofTravel     0.017215
# DayofMonth               0.016465
# DayOfWeek                0.001846
# Year                          NaN
# Name: Delivery_Status, dtype: float64

# %%
data_sin_na.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'Actual_Shipment_Time',
#        'Planned_Shipment_Time', 'Planned_Delivery_Time', 'Carrier_Name',
#        'Carrier_Num', 'Planned_TimeofTravel', 'Shipment_Delay', 'Source',
#        'Destination', 'Distance', 'Delivery_Status'],
#       dtype='object')

# %%
data_sin_na.shape
# Out:
# (1484983, 15)

# %%
data_sin_na.drop(columns = ['Year', 'Carrier_Num'], inplace = True)
#Year porque toda la data es del mismo año
#'Actual_Shipment_Time', 'Planned_Shipment_Time','Planned_Delivery_Time'
#Actual_Shipment_Time y Planned_Shipment_Time eliminados porque la resta de estos 2 es Shipment_Delay
#Carrier_Num eliminado porque ya tenemos el nombre y eso es lo que voy a utilizar

# %%
data_sin_na.shape
# Out:
# (1484983, 13)

# %%
data_sin_na.columns
# Out:
# Index(['Month', 'DayofMonth', 'DayOfWeek', 'Actual_Shipment_Time',
#        'Planned_Shipment_Time', 'Planned_Delivery_Time', 'Carrier_Name',
#        'Planned_TimeofTravel', 'Shipment_Delay', 'Source', 'Destination',
#        'Distance', 'Delivery_Status'],
#       dtype='object')

# %% [markdown]
# #### Revision de outliers ####

# %%
data_sin_na.describe()
# Out:
#               Month    DayofMonth     DayOfWeek  Actual_Shipment_Time  \
# count  1.484983e+06  1.484983e+06  1.484983e+06          1.484983e+06
# mean   3.489202e+00  1.550978e+01  3.984052e+00          1.468204e+03
# std    1.727388e+00  8.795583e+00  1.983073e+00          4.602456e+02
# min    1.000000e+00  1.000000e+00  1.000000e+00          1.000000e+00
# 25%    2.000000e+00  8.000000e+00  2.000000e+00          1.121000e+03
# 50%    3.000000e+00  1.600000e+01  4.000000e+00          1.509000e+03
# 75%    5.000000e+00  2.300000e+01  6.000000e+00          1.837000e+03
# max    6.000000e+00  3.100000e+01  7.000000e+00          2.400000e+03
#
#        Planned_Shipment_Time  Planned_Delivery_Time  Planned_TimeofTravel  \
# count           1.484983e+06           1.484983e+06          1.484983e+06
# mean            1.430676e+03           1.596853e+03          1.343331e+02
# std             4.381621e+02           4.725187e+02          7.187610e+01
# min             0.000000e+00           0.000000e+00         -2.500000e+01
# 25%             1.100000e+03           1.249000e+03          8.000000e+01
# 50%             1.445000e+03           1.640000e+03          1.160000e+02
# 75%             1.800000e+03           2.000000e+03          1.650000e+02
# max             2.359000e+03           2.359000e+03          6.600000e+02
#
#        Shipment_Delay      Distance  Delivery_Status
# count    1.484983e+06  1.484983e+06     1.484983e+06
# mean     3.202415e+01  7.712527e+02     4.835705e-01
# std      4.836686e+01  5.769275e+02     4.997302e-01
# min      1.000000e+00  1.100000e+01     0.000000e+00
# 25%      5.000000e+00  3.400000e+02     0.000000e+00
# 50%      1.500000e+01  6.110000e+02     0.000000e+00
# 75%      3.900000e+01  1.009000e+03     1.000000e+00
# max      2.467000e+03  4.962000e+03     1.000000e+00

# %%
data_sin_na.skew()
# Out:
# C:\Users\tllt1\AppData\Local\Temp\ipykernel_4092\2211770360.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data_sin_na.skew()
# Month                    0.050859
# DayofMonth               0.022060
# DayOfWeek               -0.006358
# Actual_Shipment_Time    -0.263911
# Planned_Shipment_Time   -0.144323
# Planned_Delivery_Time   -0.577916
# Planned_TimeofTravel     1.413157
# Shipment_Delay           4.890680
# Distance                 1.518899
# Delivery_Status          0.065753
# dtype: float64

# %%
sns.boxplot(data_sin_na['Planned_TimeofTravel'])
# Out:
# C:\Users\tllt1\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Planned_TimeofTravel'>

# %%
q1 = np.percentile(data_sin_na.Planned_TimeofTravel, 25)
q3 = np.percentile(data_sin_na.Planned_TimeofTravel, 75)
iqr = q3 - q1
maximo = q3 + 1.5 * iqr
minimo = q1 - 1.5 * iqr
print(minimo, maximo)
# Out:
# -47.5 292.5

# %%
outliers_planned_time = (data_sin_na.Planned_TimeofTravel < minimo) | (data_sin_na.Planned_TimeofTravel > maximo)
sum(outliers_planned_time)
# Out:
# 65431

# %%
sns.boxplot(data_sin_na['Shipment_Delay'])
# Out:
# C:\Users\tllt1\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Shipment_Delay'>

# %%
q1 = np.percentile(data_sin_na.Shipment_Delay, 25)
q3 = np.percentile(data_sin_na.Shipment_Delay, 75)
iqr = q3 - q1
maximo = q3 + 1.5 * iqr
minimo = q1 - 1.5 * iqr
print(minimo, maximo)
# Out:
# -46.0 90.0

# %%
outliers_Shipment_Delay = (data_sin_na.Shipment_Delay < minimo) | (data_sin_na.Shipment_Delay > maximo)
sum(outliers_Shipment_Delay)
# Out:
# 130035

# %%
sns.boxplot(data_sin_na['Distance'])
# Out:
# C:\Users\tllt1\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Distance'>

# %%
q1 = np.percentile(data_sin_na.Distance, 25)
q3 = np.percentile(data_sin_na.Distance, 75)
iqr = q3 - q1
maximo = q3 + 1.5 * iqr
minimo = q1 - 1.5 * iqr
print(minimo, maximo)
# Out:
# -663.5 2012.5

# %%
outliers_Distance = (data_sin_na.Distance < minimo) | (data.Distance > maximo)
sum(outliers_Distance)
# Out:
# 73402

# %%
data_sin_na.shape
# Out:
# (1484983, 13)

# %%
(data_sin_na['Shipment_Delay'] < 0).value_counts()
# Out:
# False    1484983
# Name: Shipment_Delay, dtype: int64

# %% [markdown]
# ##### Winsorizer #####

# %%
from feature_engine.outliers import Winsorizer

# %%
winsor= Winsorizer(capping_method ='iqr',
                 tail ='both',
                 fold =1.5,
                 variables = ['Planned_TimeofTravel'])
data_sin_na['Planned_TimeofTravel'] = winsor.fit_transform(data_sin_na[['Planned_TimeofTravel']])

# %%
sns.boxplot(data_sin_na['Planned_TimeofTravel'])
# Out:
# C:\Users\tllt1\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Planned_TimeofTravel'>

# %%
winsor= Winsorizer(capping_method ='iqr',
                 tail ='both',
                 fold =1.5,
                 variables = ['Shipment_Delay'])
data_sin_na['Shipment_Delay'] = winsor.fit_transform(data_sin_na[['Shipment_Delay']])

# %%
sns.boxplot(data_sin_na['Shipment_Delay'])
# Out:
# C:\Users\tllt1\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Shipment_Delay'>

# %%
winsor= Winsorizer(capping_method ='iqr',
                 tail ='both',
                 fold =1.5,
                 variables = ['Distance'])
data_sin_na['Distance'] = winsor.fit_transform(data_sin_na[['Distance']])

# %%
sns.boxplot(data_sin_na['Distance'])
# Out:
# C:\Users\tllt1\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Distance'>

# %% [markdown]
# #### Strating Sampling ####

# %%
data_sin_na.Delivery_Status.value_counts()
# 0 = (766889/(766889+718094)) = 0.5164294810108937 = 51.61%
# 1 = (718094/(718094+766889)) = 0.48357051898910625 = 48.35%
# Out:
# 0.0    766889
# 1.0    718094
# Name: Delivery_Status, dtype: int64

# %%
data_sample = (data_sin_na.groupby('Delivery_Status', group_keys=False).apply(lambda x: x.sample(frac=0.5))).copy()

# %%
data_sample.Delivery_Status.value_counts()
# 0 = (383444/(383444+359047)) = 0.5164291553702335 =51.64%
# 1 = 359047/(359047+383444) = 0.48357084462976657 = 48.35%
# Out:
# 0.0    383444
# 1.0    359047
# Name: Delivery_Status, dtype: int64

# %%
data_sample.reset_index(inplace=True)
data_sample.drop(['index'],axis=1,inplace=True)
data_sample.head()
# Out:
#    Month  DayofMonth  DayOfWeek  Actual_Shipment_Time  Planned_Shipment_Time  \
# 0      5           5          1                1152.0                   1150
# 1      1          14          1                 946.0                    945
# 2      1          10          4                1617.0                   1610
# 3      5           8          4                 956.0                    950
# 4      4          11          5                 634.0                    630
#
#    Planned_Delivery_Time Carrier_Name  Planned_TimeofTravel  Shipment_Delay  \
# 0                   1317           F9                 147.0             2.0
# 1                   1128           YV                 103.0             1.0
# 2                   1725           WN                  75.0             7.0
# 3                   1115           WN                  85.0             6.0
# 4                    645           MQ                  75.0             4.0
#
#   Source Destination  Distance  Delivery_Status
# 0    DEN         SMF     910.0              0.0
# 1    PHX         COS     551.0              0.0
# 2    BWI         MHT     377.0              0.0
# 3    LAX         SFO     337.0              0.0
# 4    SDF         ORD     286.0              0.0

# %% [markdown]
# #### Agregando Delay_cat para utlizar los rangos ####

# %%
data_limpio = data_sample.copy()
data_limpio.head(5)
# Out:
#    Month  DayofMonth  DayOfWeek  Actual_Shipment_Time  Planned_Shipment_Time  \
# 0      5           5          1                1152.0                   1150
# 1      1          14          1                 946.0                    945
# 2      1          10          4                1617.0                   1610
# 3      5           8          4                 956.0                    950
# 4      4          11          5                 634.0                    630
#
#    Planned_Delivery_Time Carrier_Name  Planned_TimeofTravel  Shipment_Delay  \
# 0                   1317           F9                 147.0             2.0
# 1                   1128           YV                 103.0             1.0
# 2                   1725           WN                  75.0             7.0
# 3                   1115           WN                  85.0             6.0
# 4                    645           MQ                  75.0             4.0
#
#   Source Destination  Distance  Delivery_Status
# 0    DEN         SMF     910.0              0.0
# 1    PHX         COS     551.0              0.0
# 2    BWI         MHT     377.0              0.0
# 3    LAX         SFO     337.0              0.0
# 4    SDF         ORD     286.0              0.0

# %%
data_limpio['Delay_brackets'] = data_limpio.Shipment_Delay

# %%
data_limpio.to_csv('data_limpio.csv', index=False)

# %%
data_limpio.head(2)
# Out:
#    Month  DayofMonth  DayOfWeek  Actual_Shipment_Time  Planned_Shipment_Time  \
# 0      5           7          3                1925.0                   1923
# 1      1          17          4                1428.0                   1421
#
#    Planned_Delivery_Time Carrier_Name  Planned_TimeofTravel  Shipment_Delay  \
# 0                   2052           NW                  89.0             2.0
# 1                   1620           NW                 119.0             7.0
#
#   Source Destination  Distance  Delivery_Status  Delay_brackets
# 0    DTW         DCA     405.0              0.0             2.0
# 1    LGA         DTW     501.0              0.0             7.0

# %%
data_limpio.Shipment_Delay.value_counts()
# Out:
# 90.0    66855
# 1.0     59444
# 2.0     44469
# 3.0     36624
# 4.0     30980
#         ...
# 83.0     1339
# 86.0     1253
# 87.0     1234
# 89.0     1222
# 88.0     1190
# Name: Shipment_Delay, Length: 90, dtype: int64

# %% [markdown]
# ###### Funcion para cambiar shipment delay como categorica ######

# %%
#def delay_convert(num):
    #num= (num)
        
#    if num > 0 and num <= 5:
#        num = 'Retardo_5'
#        return num
    
#    if num > 5.0 and num <= 10:
#        num = 'Retardo_10'
#        return num
    
#    if num > 10.0 and num <= 15:
#        num = 'Retardo_15'
#        return num
    
#    if num > 15.0 and num <= 20:
#        num = 'Retardo_20'
#        return num
    
#    if num > 20.0 and num <= 25:
#        num = 'Retardo_25'
#        return num
    
#    if num > 25:
#        num = 'Retardo_25+'
#        return num
    
#    else:
#        return num

# %%
#data_limpio.Delay_cat = data_limpio.Delay_cat.apply(delay_convert)
#data_limpio.Delay_cat.value_counts()
# Out:
# Antes_planeado    880597
# Retardo_25+       261600
# Retardo_5         201182
# En_tiempo         138040
# Retardo_10        108231
# Retardo_15         73986
# Retardo_20         55022
# Retardo_25         42425
# Name: Delay_cat, dtype: int64

# %% [markdown]
# ###### Funcion para poner shipment delay en rangos ######

# %%
def delay_convert(num):
    #num= (num)
   
    if num <= 10:
        num = 10
        return num
    
    if num > 10.1 and num <= 20:
        num = 20
        return num
    
    if num > 20.1 and num <= 30:
        num = 30
        return num
    
    if num > 30.1 and num <= 40:
        num = 40
        return num
    
    if num > 40.1 and num <= 50:
        num = 50
        return num
    
    if num > 50.1 and num <= 60:
        num = 50
        return num
    
    if num > 60.1 and num <= 70:
        num = 70
        return num    
    
    if num > 70.1 and num <= 80:
        num = 80
        return num
    
    if num > 80.1:
        num = 81
        return num
    
    else:
        return num

# %%
data_limpio.Delay_brackets = data_limpio.Delay_brackets.apply(delay_convert)
data_limpio.Delay_brackets.value_counts()
# Out:
# 10    309314
# 20    128841
# 81     78794
# 30     76160
# 50     62584
# 40     49464
# 70     20777
# 80     16557
# Name: Delay_brackets, dtype: int64

# %%
data_limpio.columns
# Out:
# Index(['Month', 'DayofMonth', 'DayOfWeek', 'Actual_Shipment_Time',
#        'Planned_Shipment_Time', 'Planned_Delivery_Time', 'Carrier_Name',
#        'Planned_TimeofTravel', 'Shipment_Delay', 'Source', 'Destination',
#        'Distance', 'Delivery_Status', 'Delay_brackets'],
#       dtype='object')

# %%
data_limpio.dtypes
# Out:
# Month                      int64
# DayofMonth                 int64
# DayOfWeek                  int64
# Actual_Shipment_Time     float64
# Planned_Shipment_Time      int64
# Planned_Delivery_Time      int64
# Carrier_Name              object
# Planned_TimeofTravel     float64
# Shipment_Delay           float64
# Source                    object
# Destination               object
# Distance                 float64
# Delivery_Status          float64
# Delay_brackets             int64
# dtype: object

# %%
data_limpio.isnull().sum()
# Out:
# Month                    0
# DayofMonth               0
# DayOfWeek                0
# Actual_Shipment_Time     0
# Planned_Shipment_Time    0
# Planned_Delivery_Time    0
# Carrier_Name             0
# Planned_TimeofTravel     0
# Shipment_Delay           0
# Source                   0
# Destination              0
# Distance                 0
# Delivery_Status          0
# Delay_brackets           0
# dtype: int64

# %%
data_limpio.shape
# Out:
# (742491, 14)

# %%
#data_limpio.to_csv('data_limpio.csv', index=False)

# %%
data_limpio.drop(columns = ['Shipment_Delay'], inplace = True)

# %%
data_limpio.shape
# Out:
# (742491, 13)

# %%
data_limpio.corr()['Delivery_Status'].apply(lambda x: np.abs(x)).sort_values(ascending = False)
# Out:
# Delivery_Status          1.000000
# Delay_brackets           0.758753
# Actual_Shipment_Time     0.218638
# Planned_Shipment_Time    0.155733
# Planned_Delivery_Time    0.135015
# Distance                 0.031348
# Month                    0.018972
# DayofMonth               0.017859
# Planned_TimeofTravel     0.016154
# DayOfWeek                0.002561
# Name: Delivery_Status, dtype: float64

# %%
data_limpio.reset_index(inplace=True)

# %%
data_limpio.drop(['index'], axis=1,inplace=True)

# %%
data_limpio.head(2)
# Out:
#    Month  DayofMonth  DayOfWeek  Actual_Shipment_Time  Planned_Shipment_Time  \
# 0      5           7          3                1925.0                   1923
# 1      1          17          4                1428.0                   1421
#
#    Planned_Delivery_Time Carrier_Name  Planned_TimeofTravel Source  \
# 0                   2052           NW                  89.0    DTW
# 1                   1620           NW                 119.0    LGA
#
#   Destination  Distance  Delivery_Status  Delay_brackets
# 0         DCA     405.0              0.0              10
# 1         DTW     501.0              0.0              10

# %%
data_limpio.shape
# Out:
# (742491, 13)

# %% [markdown]
# #### Instalacion de librerias ####

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import RobustScaler, OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn import tree
import sklearn.metrics
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
pip install feature-engine
# Out:
# Requirement already satisfied: feature-engine in c:\users\tllt1\anaconda3\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\tllt1\anaconda3\lib\site-packages (from feature-engine) (1.21.5)
# Requirement already satisfied: pandas>=1.0.3 in c:\users\tllt1\anaconda3\lib\site-packages (from feature-engine) (1.4.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\tllt1\anaconda3\lib\site-packages (from feature-engine) (1.7.3)
# Requirement already satisfied: statsmodels>=0.11.1 in c:\users\tllt1\anaconda3\lib\site-packages (from feature-engine) (0.13.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\tllt1\anaconda3\lib\site-packages (from feature-engine) (1.0.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tllt1\anaconda3\lib\site-packages (from pandas>=1.0.3->feature-engine) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\tllt1\anaconda3\lib\site-packages (from pandas>=1.0.3->feature-engine) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\tllt1\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.0.3->feature-engine) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tllt1\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->feature-engine) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\tllt1\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->feature-engine) (1.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\tllt1\anaconda3\lib\site-packages (from statsmodels>=0.11.1->feature-engine) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\tllt1\anaconda3\lib\site-packages (from statsmodels>=0.11.1->feature-engine) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\tllt1\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.11.1->feature-engine) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from feature_engine import imputation as imp
from feature_engine import encoding as enc
from feature_engine.wrappers import SklearnTransformerWrapper
from feature_engine.encoding import OneHotEncoder
from feature_engine import imputation as mdi
from feature_engine.encoding import CountFrequencyEncoder

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\tllt1\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\tllt1\anaconda3\lib\site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\tllt1\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tllt1\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\tllt1\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.7.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\tllt1\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.21.5)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\tllt1\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.0.2)

# %%
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTENC

# %%
import graphviz

# %%
from sklearn.impute import SimpleImputer

# %% [markdown]
# #### Separacion Train / Test ####

# %%
X_train, X_test, y_train, y_test = train_test_split(data_limpio.drop(columns = ['Delivery_Status']), data_limpio.Delivery_Status, test_size = 0.2, random_state = 5555)

# %%
X_train.shape
# Out:
# (593992, 12)

# %%
X_test.shape
# Out:
# (148499, 12)

# %%
y_train.shape
# Out:
# (593992,)

# %%
y_test.shape
# Out:
# (148499,)

# %% [markdown]
# #### Over/Under Sampling ####

# %%
#oversampler = RandomOverSampler()
#undersampler = RandomUnderSampler()

# %%
X_train_over, y_train_over = oversampler.fit_resample(X_train, y_train)

# %%
print('X_train_over shape = ', X_train_over.shape)
print('y_train_over shape = ', y_train_over.shape)
print('y_train_over value counts = ', y_train_over.value_counts())
# Out:
# X_train_over shape =  (2244102, 12)
# y_train_over shape =  (2244102,)
# y_train_over value counts =  0.0    1122051
# 1.0    1122051
# Name: Delivery_Status, dtype: int64

# %%
X_train_under, y_train_under = undersampler.fit_resample(X_train, y_train)

# %%
print('X_train_under shape = ', X_train_under.shape)
print('y_train_under shape = ', y_train_under.shape)
print('y_train_under value counts = ', y_train_under.value_counts())
# Out:
# X_train_under shape =  (573630, 12)
# y_train_under shape =  (573630,)
# y_train_under value counts =  0.0    286815
# 1.0    286815
# Name: Delivery_Status, dtype: int64

# %%
X_train.head(2)
# Out:
#          Month  DayofMonth  DayOfWeek  Actual_Shipment_Time  \
# 873541       2          15          5                1035.0
# 1391935      5          30          5                 740.0
#
#          Planned_Shipment_Time  Planned_Delivery_Time Carrier_Name  \
# 873541                    1020                   1229           US
# 1391935                    745                   1135           AA
#
#          Planned_TimeofTravel Source Destination  Distance       Delay_cat
# 873541                  129.0    BDL         CLT     644.0      Retardo_15
# 1391935                 230.0    EWR         SJU    1608.0  Antes_planeado

# %%
X_train.columns
# Out:
# Index(['Month', 'DayofMonth', 'DayOfWeek', 'Actual_Shipment_Time',
#        'Planned_Shipment_Time', 'Planned_Delivery_Time', 'Carrier_Name',
#        'Planned_TimeofTravel', 'Source', 'Destination', 'Distance',
#        'Delay_cat'],
#       dtype='object')

# %%
#cat = [4, 7, 8, 10]
#sm = SMOTENC(categorical_features= cat, random_state=55)
#X_train_smote, y_train_smote = sm.fit_resample(X_train, y_train)

# %% [markdown]
# #### Creacion de modelos #####

# %%
data_limpio.Delivery_Status.value_counts()
# Out:
# 0.0    383444
# 1.0    359047
# Name: Delivery_Status, dtype: int64

# %%
data_limpio.columns
# Out:
# Index(['Month', 'DayofMonth', 'DayOfWeek', 'Actual_Shipment_Time',
#        'Planned_Shipment_Time', 'Planned_Delivery_Time', 'Carrier_Name',
#        'Planned_TimeofTravel', 'Source', 'Destination', 'Distance',
#        'Delivery_Status', 'Delay_brackets'],
#       dtype='object')

# %%
pipeline_delivery = Pipeline([('escalar', SklearnTransformerWrapper(StandardScaler(), variables=['Month', 'DayofMonth', 'DayOfWeek', 'Actual_Shipment_Time', 'Planned_Shipment_Time', 'Planned_Delivery_Time',
                                                                                                 'Planned_TimeofTravel', 'Delay_brackets', 'Distance'])),
                               #('one_hot', enc.OneHotEncoder(variables = ['Delay_cat'])), 
                              ('freq_enc', enc.CountFrequencyEncoder(variables = ['Carrier_Name','Source','Destination'], encoding_method='count', unseen = 'encode')),
                                   #('modelo', DecisionTreeClassifier())
                                   ], verbose = True)
pipeline_delivery.fit(X_train, y_train)
# Out:
# [Pipeline] ........... (step 1 of 2) Processing escalar, total=   0.6s
# [Pipeline] .......... (step 2 of 2) Processing freq_enc, total=   0.6s
# Pipeline(steps=[('escalar',
#                  SklearnTransformerWrapper(transformer=StandardScaler(),
#                                            variables=['Month', 'DayofMonth',
#                                                       'DayOfWeek',
#                                                       'Actual_Shipment_Time',
#                                                       'Planned_Shipment_Time',
#                                                       'Planned_Delivery_Time',
#                                                       'Planned_TimeofTravel',
#                                                       'Delay_brackets',
#                                                       'Distance'])),
#                 ('freq_enc',
#                  CountFrequencyEncoder(unseen='encode',
#                                        variables=['Carrier_Name', 'Source',
#                                                   'Destination']))],
#          verbose=True)

# %%
X_train_transformed = pipeline_delivery.transform(X_train)

# %%
X_train_transformed.head(3)
# Out:
#            Month  DayofMonth  DayOfWeek  Actual_Shipment_Time  \
# 393033 -1.441137    0.964790   0.007518             -0.767403
# 519470  1.452068   -0.057189   1.520952             -0.494011
# 488224  0.873427   -0.057189   0.007518              0.310975
#
#         Planned_Shipment_Time  Planned_Delivery_Time  Carrier_Name  \
# 393033              -0.855717              -0.778819         40796
# 519470              -0.474970              -0.558633         43750
# 488224               0.193045               0.267064         21957
#
#         Planned_TimeofTravel  Source  Destination  Distance  Delay_brackets
# 393033              0.336763     983        31250 -0.053381       -0.404047
# 519470             -0.016190   22311         3728  0.132598       -0.404047
# 488224             -0.062227     229        28750 -0.113436        0.820855

# %%
X_train.head(3)
# Out:
#         Month  DayofMonth  DayOfWeek  Actual_Shipment_Time  \
# 393033      1          24          4                1114.0
# 519470      6          15          7                1240.0
# 488224      5          15          4                1611.0
#
#         Planned_Shipment_Time  Planned_Delivery_Time Carrier_Name  \
# 393033                   1055                   1229           MQ
# 519470                   1222                   1333           UA
# 488224                   1515                   1723           EV
#
#         Planned_TimeofTravel Source Destination  Distance  Delay_brackets
# 393033                 154.0    ALB         ORD     723.0              20
# 519470                 131.0    DEN         ONT     819.0              20
# 488224                 128.0    ABE         ATL     692.0              50

# %% [markdown]
# ##### Logistic Regression #####

# %%
logreg = LogisticRegression()

# %%
regression = logreg.fit(X_train_transformed, y_train)

# %%
pred_train = regression.predict(X_train_transformed)
pred_train
# Out:
# array([1., 0., 1., ..., 0., 0., 1.])

# %%
pred_train_probas = regression.predict_proba(X_train_transformed)[:,1]
pred_train_probas
# Out:
# array([0.518829  , 0.49367064, 0.53145649, ..., 0.4974306 , 0.391018  ,
#        0.50549798])

# %%
metrics.roc_auc_score(y_train, pred_train)
# Out:
# 0.5318980458282248

# %%
metrics.roc_auc_score(y_train, pred_train_probas)
# Out:
# 0.5474568627013401

# %%
regression_test = pipeline_delivery.transform(X_test)
# Out:
# C:\Users\tllt1\anaconda3\lib\site-packages\feature_engine\encoding\base_encoder.py:210: UserWarning: During the encoding, NaN values were introduced in the feature(s) Destination.
#   warnings.warn(

# %%
#pred_simple_regression_test = regression.predict(regression_test)

# %%
#pred_proba_regression_test = regression.predict_proba(regression_test)

# %%
#metrics.plot_confusion_matrix(logreg, X_train_transformed, y_train_over)

# %%
metrics.roc_auc_score(y_test, pred_simple_regression_test)
# Out:
# 1.0

# %%
metrics.roc_auc_score(y_test, pred_proba_regression_test[:,1])
# Out:
# 1.0

# %% [markdown]
# ##### Tree Classifier #####

# %%
dec_tree = DecisionTreeClassifier()
params = {'splitter':['random', 'best'], 'max_depth' : [50, 100, 150], 'random_state':[525]}
cvtree = GridSearchCV(dec_tree, params).fit(X_train_transformed, y_train)# X_TRAIN = DATA

# %%
cvtree.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=50, random_state=525, splitter='random')

# %%
tree_classifier_full = DecisionTreeClassifier(splitter = 'random',  max_depth = 50, random_state=525).fit(X_train_transformed, y_train)

# %%
tree_classifier_full.feature_importances_
# Out:
# array([0.00293568, 0.00547121, 0.00426017, 0.07685852, 0.05762571,
#        0.00394534, 0.00262872, 0.00389759, 0.00416789, 0.00416631,
#        0.00404934, 0.82999353])

# %%
tree_classifier_full.feature_names_in_
# Out:
# array(['Month', 'DayofMonth', 'DayOfWeek', 'Actual_Shipment_Time',
#        'Planned_Shipment_Time', 'Planned_Delivery_Time', 'Carrier_Name',
#        'Planned_TimeofTravel', 'Source', 'Destination', 'Distance',
#        'Delay_brackets'], dtype=object)

# %%
importances = pd.DataFrame(data = {'attribute': tree_classifier_full.feature_names_in_, 'importance': tree_classifier_full.feature_importances_})
importances = importances.sort_values(by= 'importance', ascending=False)
importances
# Out:
#                 attribute  importance
# 11         Delay_brackets    0.829994
# 3    Actual_Shipment_Time    0.076859
# 4   Planned_Shipment_Time    0.057626
# 1              DayofMonth    0.005471
# 2               DayOfWeek    0.004260
# 8                  Source    0.004168
# 9             Destination    0.004166
# 10               Distance    0.004049
# 5   Planned_Delivery_Time    0.003945
# 7    Planned_TimeofTravel    0.003898
# 0                   Month    0.002936
# 6            Carrier_Name    0.002629

# %%
plt.bar(x=importances['attribute'], height=importances['importance'], color='#06C2A6')
plt.title('Feature importances obtained from coefficients', size=20)
plt.xticks(rotation='vertical')
plt.show()

# %%
pred_simple = tree_classifier_full.predict(X_train_transformed)
pred_simple
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])

# %%
predict_probas = tree_classifier_full.predict_proba(X_train_transformed)
predict_probas
# Out:
# array([[0., 1.],
#        [0., 1.],
#        [0., 1.],
#        ...,
#        [1., 0.],
#        [1., 0.],
#        [1., 0.]])

# %%
sklearn.metrics.roc_auc_score(y_train, predict_probas[:,1])
# Out:
# 1.0

# %%
metrics.accuracy_score(y_train, pred_simple)
# Out:
# 1.0

# %%
test_tree = pipeline_delivery.transform(X_test)

# %%
X_test.isnull()
# Out:
#         Month  DayofMonth  DayOfWeek  Actual_Shipment_Time  \
# 138655  False       False      False                 False
# 592406  False       False      False                 False
# 28583   False       False      False                 False
# 475740  False       False      False                 False
# 343519  False       False      False                 False
# ...       ...         ...        ...                   ...
# 207737  False       False      False                 False
# 117736  False       False      False                 False
# 226006  False       False      False                 False
# 6536    False       False      False                 False
# 560851  False       False      False                 False
#
#         Planned_Shipment_Time  Planned_Delivery_Time  Carrier_Name  \
# 138655                  False                  False         False
# 592406                  False                  False         False
# 28583                   False                  False         False
# 475740                  False                  False         False
# 343519                  False                  False         False
# ...                       ...                    ...           ...
# 207737                  False                  False         False
# 117736                  False                  False         False
# 226006                  False                  False         False
# 6536                    False                  False         False
# 560851                  False                  False         False
#
#         Planned_TimeofTravel  Source  Destination  Distance  Delay_brackets
# 138655                 False   False        False     False           False
# 592406                 False   False        False     False           False
# 28583                  False   False        False     False           False
# 475740                 False   False        False     False           False
# 343519                 False   False        False     False           False
# ...                      ...     ...          ...       ...             ...
# 207737                 False   False        False     False           False
# 117736                 False   False        False     False           False
# 226006                 False   False        False     False           False
# 6536                   False   False        False     False           False
# 560851                 False   False        False     False           False
#
# [148499 rows x 12 columns]

# %%
pred_simple_test_tree = tree_classifier_full.predict(test_tree)

# %%
metrics.roc_auc_score(y_test, pred_simple_test_tree)
# Out:
# 0.977472701838305

# %%
pred_proba_test_tree = tree_classifier_full.predict_proba(test_tree)

# %%
metrics.roc_auc_score(y_test, pred_proba_test_tree[:,1])
# Out:
# 0.977472701838305

# %%
metrics.plot_confusion_matrix(tree_classifier_full, X_train_transformed, y_train)
# Out:
# C:\Users\tllt1\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ##### Forest #####

# %%
forest = RandomForestClassifier()
params = {'max_depth': [10, 30, 35], 'n_estimators':[5, 6, 7]}
grid_forest = GridSearchCV(forest, params).fit(X_train_transformed, y_train_under)

# %%
grid_forest.best_estimator_
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=5)

# %%
best_forest = RandomForestClassifier(max_depth=10, n_estimators=5).fit(X_train_transformed, y_train)

# %%
importances = pd.DataFrame(data = {'Variable': best_forest.feature_names_in_, 'Importance': best_forest.feature_importances_})
importances = importances.sort_values(by= 'Importance', ascending=False)
importances
# Out:
#                  Variable  Importance
# 11         Delay_brackets    0.909961
# 3    Actual_Shipment_Time    0.041409
# 4   Planned_Shipment_Time    0.023330
# 5   Planned_Delivery_Time    0.009196
# 6            Carrier_Name    0.009130
# 9             Destination    0.002745
# 8                  Source    0.001609
# 7    Planned_TimeofTravel    0.001077
# 10               Distance    0.000738
# 1              DayofMonth    0.000376
# 2               DayOfWeek    0.000226
# 0                   Month    0.000203

# %%
plt.bar(x=importances['Variable'], height=importances['Importance'], color='#06C2A6')
plt.title('Importance per variable', size=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize =(10, 7))

# Horizontal Bar Plot
ax.barh(importances['Variable'].head(6),importances['Importance'].head(6), color='#06C2A6')
plt.yticks(fontsize=12)

# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

    # Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)

# Show top values 
ax.invert_yaxis()

# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.02, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 12, fontweight ='bold',
             color ='grey')

# Add Plot Title
ax.set_title('Importance per variable',
             loc ='center', size=15 )

plt.show()
# Out:
# C:\Users\tllt1\AppData\Local\Temp\ipykernel_4092\2037593366.py:20: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b = True, color ='grey',

# %%
pred_simple_forest = best_forest.predict(X_train_transformed)
pred_simple_forest
# Out:
# array([1., 0., 1., ..., 0., 0., 0.])

# %%
metrics.roc_auc_score(y_train, pred_simple_forest)
# Out:
# 0.9268262288591965

# %%
predict_proba_forest = best_forest.predict_proba(X_train_transformed)
predict_proba_forest
# Out:
# array([[0.47974397, 0.52025603],
#        [0.69908049, 0.30091951],
#        [0.        , 1.        ],
#        ...,
#        [0.96830409, 0.03169591],
#        [0.98519531, 0.01480469],
#        [0.8719956 , 0.1280044 ]])

# %%
metrics.roc_auc_score(y_train, predict_proba_forest[:,1])
# Out:
# 0.9880073372701481

# %%
metrics.plot_confusion_matrix(best_forest, X_train_transformed, y_train, cmap='GnBu')
# Out:
# C:\Users\tllt1\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.metrics import confusion_matrix

# %%
cf_matrix = confusion_matrix(y_train, pred_simple_forest)
print(cf_matrix)
# Out:
# [[306777    351]
#  [ 41654 245210]]

# %%
group_names = ['Demora - acertados','En tiempo - no acertado','Demora - no acertado','En tiempo - acertado']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='GnBu')
# Out:
# <AxesSubplot:>

# %%
test_forest = pipeline_delivery.transform(X_test)

# %%
pred_data_test = best_forest.predict(test_forest)

# %%
metrics.roc_auc_score(y_test, pred_data_test)
# Out:
# 0.9267135753536003

# %%
pred_proba_data_test = best_forest.predict_proba(test_forest)

# %%
metrics.roc_auc_score(y_test, pred_proba_data_test[:,1])
# Out:
# 0.9874020003080831
